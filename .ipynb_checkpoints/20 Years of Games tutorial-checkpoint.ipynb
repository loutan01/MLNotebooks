# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import datetime
# %matplotlib inline

# %%
sns.set_palette('Set3', 10)
sns.palplot(sns.color_palette())
sns.set_context('talk')

# %%
rawData = pd.read_csv('ign.csv')

# %%
type(rawData)
# Out:
# pandas.core.frame.DataFrame

# %%
rawData.head()
#same as rawData.iloc[0:5,:]
# Out:
#    Unnamed: 0 score_phrase                                              title  \
# 0           0      Amazing                            LittleBigPlanet PS Vita
# 1           1      Amazing  LittleBigPlanet PS Vita -- Marvel Super Hero E...
# 2           2        Great                               Splice: Tree of Life
# 3           3        Great                                             NHL 13
# 4           4        Great                                             NHL 13
#
#                                                  url          platform  score  \
# 0             /games/littlebigplanet-vita/vita-98907  PlayStation Vita    9.0
# 1  /games/littlebigplanet-ps-vita-marvel-super-he...  PlayStation Vita    9.0
# 2                          /games/splice/ipad-141070              iPad    8.5
# 3                      /games/nhl-13/xbox-360-128182          Xbox 360    8.5
# 4                           /games/nhl-13/ps3-128181     PlayStation 3    8.5
#
# ...

# %%
rawData.shape
# Out:
# (18625, 10)

# %% [markdown]
# # E.T. phone home

# %%
rawData[rawData['title'].str.contains("E.T.")]
# Out:
#       Unnamed: 0 score_phrase                       title  \
# 3882        3882        Awful  E.T. The Extra-Terrestrial
# 4609        4609        Great   .hack//INFECTION (Part 1)
#
#                                                    url          platform  \
# 3882  /games/et-the-extra-terrestrial-945952/gba-15925  Game Boy Advance
# 4609          /games/hackinfection-demo-disc/ps2-17477     PlayStation 2
#
#       score        genre editors_choice  release_year  release_month  \
# 3882    3.5       Action              N          2002              6
# 4609    8.5  Action, RPG              Y          2003              2
#
#       release_day
# 3882           14
# 4609           10

# %%
rawData = rawData.drop('Unnamed: 0', axis = 1) #the access parameter is used to determine row
#same as rawData = rawData.iloc[:,1:]

# %%
rawData
# Out:
#       score_phrase                                              title  \
# 0          Amazing                            LittleBigPlanet PS Vita
# 1          Amazing  LittleBigPlanet PS Vita -- Marvel Super Hero E...
# 2            Great                               Splice: Tree of Life
# 3            Great                                             NHL 13
# 4            Great                                             NHL 13
# 5             Good                          Total War Battles: Shogun
# 6            Awful                                Double Dragon: Neon
# 7          Amazing                                       Guild Wars 2
# 8            Awful                                Double Dragon: Neon
# 9             Good                          Total War Battles: Shogun
# 10            Good                            Tekken Tag Tournament 2
# 11            Good                            Tekken Tag Tournament 2
# ...

# %%
some_reviews = rawData.iloc[10:20,]
some_reviews.head()
# Out:
#    score_phrase                    title  \
# 10         Good  Tekken Tag Tournament 2
# 11         Good  Tekken Tag Tournament 2
# 12         Good               Wild Blood
# 13      Amazing        Mark of the Ninja
# 14      Amazing        Mark of the Ninja
#
#                                                 url       platform  score  \
# 10        /games/tekken-tag-tournament-2/ps3-124584  PlayStation 3    7.5
# 11   /games/tekken-tag-tournament-2/xbox-360-124581       Xbox 360    7.5
# 12                  /games/wild-blood/iphone-139363         iPhone    7.0
# 13  /games/mark-of-the-ninja-135615/xbox-360-129276       Xbox 360    9.0
# 14        /games/mark-of-the-ninja-135615/pc-143761             PC    9.0
#
#                 genre editors_choice  release_year  release_month  release_day
# 10           Fighting              N          2012              9           11
# 11           Fighting              N          2012              9           11
# ...

# %%
#As we mentioned earlier, column labels can make life much easier when you’re working with data. 
#We can specify column labels in the loc method to retrieve columns by label instead of by position.
rawData.loc[:5,"score"]
# Out:
# 0    9.0
# 1    9.0
# 2    8.5
# 3    8.5
# 4    8.5
# 5    7.0
# Name: score, dtype: float64

# %%
rawData.loc[:5,["score","release_year"]]
# Out:
#    score  release_year
# 0    9.0          2012
# 1    9.0          2012
# 2    8.5          2012
# 3    8.5          2012
# 4    8.5          2012
# 5    7.0          2012

# %%
rawData[["score", "release_year"]]
# Out:
#        score  release_year
# 0        9.0          2012
# 1        9.0          2012
# 2        8.5          2012
# 3        8.5          2012
# 4        8.5          2012
# 5        7.0          2012
# 6        3.0          2012
# 7        9.0          2012
# 8        3.0          2012
# 9        7.0          2012
# 10       7.5          2012
# 11       7.5          2012
# 12       7.0          2012
# 13       9.0          2012
# 14       9.0          2012
# 15       6.5          2012
# 16       6.5          2012
# 17       8.0          2012
# 18       5.5          2012
# 19       7.0          2012
# 20       7.0          2012
# 21       7.5          2012
# 22       7.5          2012
# 23       7.5          2012
# 24       9.0          2012
# 25       7.0          2012
# 26       9.0          2012
# 27       7.5          2012
# 28       8.0          2012
# 29       6.5          2012
# ...      ...           ...
# 18595    4.4          2016
# 18596    6.5          2016
# ...

# %%
#create a dataframe from a series...
s1 = pd.Series([1,2])
s2 = pd.Series(["Boris Yeltsin", "Mikhail Gorbachev"])
pd.DataFrame([s1,s2])
# Out:
#                0                  1
# 0              1                  2
# 1  Boris Yeltsin  Mikhail Gorbachev

# %%
#can also be done this way:
frame = pd.DataFrame(
    [
        [1,2],
        ["Boris Yeltsin", "Mikhail Gorbachev"]
    ],
    index=["row1", "row2"],
    columns=["column1", "column2"]
)
frame
# Out:
#             column1            column2
# row1              1                  2
# row2  Boris Yeltsin  Mikhail Gorbachev

# %%
#math...
rawData["score"].mean()
# Out:
# 6.950459060402685

# %%
rawData["score"] / 2
# Out:
# 0        4.50
# 1        4.50
# 2        4.25
# 3        4.25
# 4        4.25
# 5        3.50
# 6        1.50
# 7        4.50
# 8        1.50
# 9        3.50
# 10       3.75
# 11       3.75
# 12       3.50
# 13       4.50
# 14       4.50
# 15       3.25
# 16       3.25
# 17       4.00
# 18       2.75
# 19       3.50
# 20       3.50
# 21       3.75
# 22       3.75
# 23       3.75
# 24       4.50
# 25       3.50
# 26       4.50
# 27       3.75
# 28       4.00
# 29       3.25
#          ...
# 18595    2.20
# 18596    3.25
# 18597    2.45
# 18598    3.40
# 18599    3.50
# 18600    3.70
# 18601    3.70
# 18602    3.70
# 18603    3.90
# 18604    4.30
# 18605    3.00
# 18606    3.20
# 18607    3.50
# 18608    2.70
# 18609    4.00
# 18610    3.00
# 18611    2.90
# 18612    3.90
# 18613    4.00
# 18614    4.60
# 18615    4.60
# 18616    3.75
# 18617    4.20
# 18618    4.55
# 18619    3.95
# 18620    3.80
# 18621    4.50
# 18622    2.90
# 18623    5.00
# 18624    5.00
# ...

# %%
score_filter = rawData["score"] > 7
score_filter
# Out:
# 0         True
# 1         True
# 2         True
# 3         True
# 4         True
# 5        False
# 6        False
# 7         True
# 8        False
# 9        False
# 10        True
# 11        True
# 12       False
# 13        True
# 14        True
# 15       False
# 16       False
# 17        True
# 18       False
# 19       False
# 20       False
# 21        True
# 22        True
# 23        True
# 24        True
# 25       False
# 26        True
# 27        True
# 28        True
# 29       False
#          ...
# 18595    False
# 18596    False
# 18597    False
# 18598    False
# 18599    False
# 18600     True
# 18601     True
# 18602     True
# 18603     True
# 18604     True
# 18605    False
# 18606    False
# 18607    False
# 18608    False
# 18609     True
# 18610    False
# 18611    False
# 18612     True
# 18613     True
# 18614     True
# 18615     True
# 18616     True
# 18617     True
# 18618     True
# 18619     True
# 18620     True
# 18621     True
# ...

# %%
filtered_reviews = rawData[score_filter]
filtered_reviews.head()
# Out:
#   score_phrase                                              title  \
# 0      Amazing                            LittleBigPlanet PS Vita
# 1      Amazing  LittleBigPlanet PS Vita -- Marvel Super Hero E...
# 2        Great                               Splice: Tree of Life
# 3        Great                                             NHL 13
# 4        Great                                             NHL 13
#
#                                                  url          platform  score  \
# 0             /games/littlebigplanet-vita/vita-98907  PlayStation Vita    9.0
# 1  /games/littlebigplanet-ps-vita-marvel-super-he...  PlayStation Vita    9.0
# 2                          /games/splice/ipad-141070              iPad    8.5
# 3                      /games/nhl-13/xbox-360-128182          Xbox 360    8.5
# 4                           /games/nhl-13/ps3-128181     PlayStation 3    8.5
#
#         genre editors_choice  release_year  release_month  release_day
# ...

# %%
xbox_one_filter = (rawData["score"] > 7) & (rawData["platform"] == "Xbox One")
filtered_reviews = rawData[xbox_one_filter]
filtered_reviews.head()
# Out:
#       score_phrase                     title  \
# 17137      Amazing                 Gone Home
# 17197      Amazing            Rayman Legends
# 17295      Amazing  LEGO Marvel Super Heroes
# 17313        Great             Dead Rising 3
# 17317        Great           Killer Instinct
#
#                                                      url  platform  score  \
# 17137                 /games/gone-home/xbox-one-20014361  Xbox One    9.5
# 17197            /games/rayman-legends/xbox-one-20008449  Xbox One    9.5
# 17295  /games/lego-marvel-super-heroes/xbox-one-20000826  Xbox One    9.0
# 17313               /games/dead-rising-3/xbox-one-124306  Xbox One    8.3
# 17317      /games/killer-instinct-2013/xbox-one-20000538  Xbox One    8.4
#
#             genre editors_choice  release_year  release_month  release_day
# 17137  Simulation              Y          2013              8           15
# 17197  Platformer              Y          2013              8           26
# ...

# %%
rawData[rawData["platform"] == "Xbox One"]["score"].plot(kind="hist")

# %%
rawData[rawData["platform"] == "PlayStation 4"]["score"].plot(kind="hist")

# %%
filtered_reviews["score"].hist()

# %% [markdown]
# # Worst Games ever...

# %%
rawData.sort_values('score')
# Out:
#       score_phrase                                     title  \
# 5242      Disaster   Looney Tunes: Back in Action: Zany Race
# 890       Disaster                        Extreme PaintBrawl
# 12513     Disaster                       Action Girlz Racing
# 11362   Unbearable                     Backyard Baseball '09
# 1190    Unbearable                    Freestyle Boardin' '99
# 6535    Unbearable                        NRA Varmint Hunter
# 4037    Unbearable                           NFL Blitz 20-03
# 12007   Unbearable                    Motocross Championship
# 4026    Unbearable                 Crime Patrol 2: Drug Wars
# 3074    Unbearable                    The Simpsons Wrestling
# 4944    Unbearable                          Fury of The Hulk
# 12701   Unbearable                                Mega Man 2
# 16409   Unbearable                Self-Defense Training Camp
# 10676   Unbearable                   Kidz Sports: Basketball
# ...

# %%
rawData.sort_values(['score', 'release_year', 'release_month']).head(10)
# Out:
#       score_phrase                                    title  \
# 5242      Disaster  Looney Tunes: Back in Action: Zany Race
# 890       Disaster                       Extreme PaintBrawl
# 12513     Disaster                      Action Girlz Racing
# 439     Unbearable                             Revolution X
# 496     Unbearable                             Revolution X
# 574     Unbearable                 The Crow: City of Angels
# 770     Unbearable                           Fantastic Four
# 848     Unbearable                  C: The Contra Adventure
# 1190    Unbearable                   Freestyle Boardin' '99
# 1276    Unbearable                      Extreme Watersports
#
#                                                      url     platform  score  \
# 5242   /games/looney-tunes-back-in-action-zany-race/c...     Wireless    0.5
# 890                   /games/extreme-paintbrawl/pc-10455           PC    0.7
# ...

# %%
rawData[(rawData.platform == 'PC') | (rawData.platform == 'Macintosh')].sort_values('score',ascending = False)
# Out:
#       score_phrase                                       title  \
# 18624  Masterpiece                                      Inside
# 18067  Masterpiece                          Grand Theft Auto V
# 18418  Masterpiece                                   Undertale
# 18417  Masterpiece                                   Undertale
# 18353  Masterpiece                                 The Witness
# 18434  Masterpiece        Metal Gear Solid V: The Phantom Pain
# 9669       Amazing                  BioShock (Limited Edition)
# 6308       Amazing                                 Half-Life 2
# 4670       Amazing               Black & White (Platinum Pack)
# 9668       Amazing                                    BioShock
# 3053       Amazing                               Black & White
# 6720       Amazing     Tom Clancy's Splinter Cell Chaos Theory
# 1795       Amazing                    Unreal Tournament [1999]
# 13649      Amazing       Fallout 3 -- Game of the Year Edition
# ...

# %%
#finding my favorite
rawData[rawData.title.str.contains('Skyrim')]
# Out:
#       score_phrase                                      title  \
# 286          Great  The Elder Scrolls V: Skyrim -- Dragonborn
# 16328      Amazing                The Elder Scrolls V: Skyrim
# 16352      Amazing                The Elder Scrolls V: Skyrim
# 16355      Amazing                The Elder Scrolls V: Skyrim
# 16832        Great   The Elder Scrolls V: Skyrim -- Dawnguard
# 16842        Great   The Elder Scrolls V: Skyrim -- Dawnguard
# 16843        Great   The Elder Scrolls V: Skyrim -- Dawnguard
#
#                                                      url       platform  \
# 286    /games/the-elder-scrolls-v-skyrim-dragonborn/x...       Xbox 360
# 16328        /games/the-elder-scrolls-v-skyrim/ps3-93394  PlayStation 3
# 16352  /games/the-elder-scrolls-v-skyrim/xbox-360-142...       Xbox 360
# 16355         /games/the-elder-scrolls-v-skyrim/pc-93395             PC
# 16832  /games/the-elder-scrolls-v-skyrim-dawnguard/xb...       Xbox 360
# ...

# %%
ra
